# %% [markdown]
# <a href="https://colab.research.google.com/github/Nirwa22/Project/blob/main/Box_office_Revenue_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
Data = pd.read_csv('/content/All Time Worldwide Box Office.csv')

# %%
Data
# Out:
#      Rank  Year                                 Movie WorldwideBox Office  \
# 0       1  2009                                Avatar      $2,845,899,541
# 1       2  2019                     Avengers: Endgame      $2,797,800,564
# 2       3  1997                               Titanic      $2,207,986,545
# 3       4  2015  Star Wars Ep. VII: The Force Awakens      $2,064,615,817
# 4       5  2018                Avengers: Infinity War      $2,044,540,523
# ..    ...   ...                                   ...                 ...
# 590   596  2010                        Knight and Day        $258,751,370
# 591   597  1985                         Out of Africa        $258,210,860
# 592   598  2011                               Super 8        $257,972,745
# 593   599  2013                       American Hustle        $257,858,943
# 594   600  2000                       Erin Brockovich        $257,805,243
#
#     DomesticBox Office InternationalBox Office
# ...

# %%
Data.isnull().sum()
# Out:
# Rank                       0
# Year                       0
# Movie                      0
# WorldwideBox Office        0
# DomesticBox Office         7
# InternationalBox Office    0
# dtype: int64

# %%
#Data =  Data.dropna()

# %%
Data
# Out:
#      Rank  Year                                 Movie WorldwideBox Office  \
# 0       1  2009                                Avatar      $2,845,899,541
# 1       2  2019                     Avengers: Endgame      $2,797,800,564
# 2       3  1997                               Titanic      $2,207,986,545
# 3       4  2015  Star Wars Ep. VII: The Force Awakens      $2,064,615,817
# 4       5  2018                Avengers: Infinity War      $2,044,540,523
# ..    ...   ...                                   ...                 ...
# 590   596  2010                        Knight and Day        $258,751,370
# 591   597  1985                         Out of Africa        $258,210,860
# 592   598  2011                               Super 8        $257,972,745
# 593   599  2013                       American Hustle        $257,858,943
# 594   600  2000                       Erin Brockovich        $257,805,243
#
#     DomesticBox Office InternationalBox Office
# ...

# %%
Data.isnull().sum()
# Out:
# Rank                       0
# Year                       0
# Movie                      0
# WorldwideBox Office        0
# DomesticBox Office         7
# InternationalBox Office    0
# dtype: int64

# %%
def integer(x):
  t='0123456789'
  y=''
  for i in str(x):
    if i in t:
      y=y+i
  if y!='':
    return int(y)
  else:
    return 0

# %%
Data['DomesticBox Office'] = Data['DomesticBox Office'].apply(integer)

# %%
Data['WorldwideBox Office'] = Data['WorldwideBox Office'].apply(integer)

# %%
Data['InternationalBox Office'] = Data['InternationalBox Office'].apply(integer)

# %%
Data
# Out:
#      Rank  Year                                 Movie  WorldwideBox Office  \
# 0       1  2009                                Avatar           2845899541
# 1       2  2019                     Avengers: Endgame           2797800564
# 2       3  1997                               Titanic           2207986545
# 3       4  2015  Star Wars Ep. VII: The Force Awakens           2064615817
# 4       5  2018                Avengers: Infinity War           2044540523
# ..    ...   ...                                   ...                  ...
# 590   596  2010                        Knight and Day            258751370
# 591   597  1985                         Out of Africa            258210860
# 592   598  2011                               Super 8            257972745
# 593   599  2013                       American Hustle            257858943
# 594   600  2000                       Erin Brockovich            257805243
#
#      DomesticBox Office  InternationalBox Office
# ...

# %%
Data.isnull().sum()
# Out:
# Rank                       0
# Year                       0
# Movie                      0
# WorldwideBox Office        0
# DomesticBox Office         0
# InternationalBox Office    0
# dtype: int64

# %%
Data['DomesticBox Office'] = Data['DomesticBox Office'].replace(0, Data['DomesticBox Office'].mean())

# %%
Data
# Out:
#      Rank  Year                                 Movie  WorldwideBox Office  \
# 0       1  2009                                Avatar           2845899541
# 1       2  2019                     Avengers: Endgame           2797800564
# 2       3  1997                               Titanic           2207986545
# 3       4  2015  Star Wars Ep. VII: The Force Awakens           2064615817
# 4       5  2018                Avengers: Infinity War           2044540523
# ..    ...   ...                                   ...                  ...
# 590   596  2010                        Knight and Day            258751370
# 591   597  1985                         Out of Africa            258210860
# 592   598  2011                               Super 8            257972745
# 593   599  2013                       American Hustle            257858943
# 594   600  2000                       Erin Brockovich            257805243
#
#      DomesticBox Office  InternationalBox Office
# ...

# %%
Data.duplicated().sum()
# Out:
# 0

# %%
pd.DataFrame(Data)
# Out:
#      Rank  Year                                 Movie  WorldwideBox Office  \
# 0       1  2009                                Avatar           2845899541
# 1       2  2019                     Avengers: Endgame           2797800564
# 2       3  1997                               Titanic           2207986545
# 3       4  2015  Star Wars Ep. VII: The Force Awakens           2064615817
# 4       5  2018                Avengers: Infinity War           2044540523
# ..    ...   ...                                   ...                  ...
# 590   596  2010                        Knight and Day            258751370
# 591   597  1985                         Out of Africa            258210860
# 592   598  2011                               Super 8            257972745
# 593   599  2013                       American Hustle            257858943
# 594   600  2000                       Erin Brockovich            257805243
#
#      DomesticBox Office  InternationalBox Office
# ...

# %%
Data_New = pd.DataFrame(Data)[['Rank', 'WorldwideBox Office', 'DomesticBox Office', 'InternationalBox Office']]

# %%
Data_New
# Out:
#      Rank  WorldwideBox Office  DomesticBox Office  InternationalBox Office
# 0       1           2845899541         760507625.0               2085391916
# 1       2           2797800564         858373000.0               1939427564
# 2       3           2207986545         659363944.0               1548622601
# 3       4           2064615817         936662225.0               1127953592
# 4       5           2044540523         678815482.0               1365725041
# ..    ...                  ...                 ...                      ...
# 590   596            258751370          76423035.0                182328335
# 591   597            258210860          79096868.0                179113992
# 592   598            257972745         127004179.0                130968566
# 593   599            257858943         150098456.0                107760487
# 594   600            257805243         125548685.0                132256558
#
# [595 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
X = Data_New[['Rank','WorldwideBox Office','DomesticBox Office']]
Y = Data_New['InternationalBox Office']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((446, 3), (149, 3), (446,), (149,))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
Model = LinearRegression()
Model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = Model.predict(X_test)

# %%
mse = mean_squared_error(y_test, predictions)
print(f"Mean Squared Error : {mse}")
print(f"R2_Score : {r2_score(y_test,predictions)}")
# Out:
# Mean Squared Error : 502865329048999.75
# R2_Score : 0.9926641535294277

# %% [markdown]
# ###Mean Squared error is really high.Lets try to fix it by scaling.

# %%
from sklearn.preprocessing import StandardScaler
X_train,X_test= StandardScaler().fit_transform(X_train),StandardScaler().fit_transform(X_test)

# %%
y_train,y_test = StandardScaler().fit_transform(y_train.values.reshape(-1, 1)),StandardScaler().fit_transform(y_test.values.reshape(-1, 1))

# %%
Model=LinearRegression()
Model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = Model.predict(X_test)

# %%
print(f"Mean Squared Error : {mean_squared_error(y_test, predictions)}")
print(f"R2_Score : {r2_score(y_test,predictions)}")
# Out:
# Mean Squared Error : 0.008119499625535943
# R2_Score : 0.9918805003744641

# %% [markdown]
# **Good results**
